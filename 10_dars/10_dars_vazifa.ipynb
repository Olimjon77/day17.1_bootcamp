# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("Student_data.csv")

# %%
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %% [markdown]
# ## Loc orqali o'zgartirish columdagi malumotlarni

# %%
df.loc[df["Gender"]==0, "Gender"] ="Male"
df.loc[df["Gender"]== 1, "Gender"] = 'Female'
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13136\40503052.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Male' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df["Gender"]==0, "Gender"] ="Male"

# %%
df.loc[df["Ethnicity"]==0, "Ethnicity"] = "Caucasian"
df.loc[df["Ethnicity"]==1, "Ethnicity"] = "African American"
df.loc[df["Ethnicity"]==2, "Ethnicity"] = "Asian"
df.loc[df["Ethnicity"]==3, "Ethnicity"] = "Other"
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13136\1666646371.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Caucasian' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df["Ethnicity"]==0, "Ethnicity"] = "Caucasian"

# %%
df.head(10)
# Out:
#    StudentID  Age  Gender         Ethnicity  ParentalEducation  \
# 0       1001   17  Female         Caucasian                  2
# 1       1002   18    Male         Caucasian                  1
# 2       1003   15    Male             Asian                  3
# 3       1004   17  Female         Caucasian                  3
# 4       1005   17  Female         Caucasian                  2
# 5       1006   18    Male         Caucasian                  1
# 6       1007   15    Male  African American                  1
# 7       1008   15  Female  African American                  4
# 8       1009   17    Male         Caucasian                  0
# 9       1010   16  Female         Caucasian                  1
#
#    StudyTimeWeekly  Absences  Tutoring  ParentalSupport  Extracurricular  \
# 0        19.833723         7         1                2                0
# 1        15.408756         0         0                1                0
# ...

# %%
df.loc[df["ParentalEducation"] == 0, "ParentalEducation"] = "None"
df.loc[df["ParentalEducation"] == 1, "ParentalEducation"] = "High School"
df.loc[df["ParentalEducation"] == 2, "ParentalEducation"] = "Some College"
df.loc[df["ParentalEducation"] == 3, "ParentalEducation"] = "Bachelor's"
df.loc[df["ParentalEducation"] == 4, "ParentalEducation"] = "Higher"

# %%
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity ParentalEducation  StudyTimeWeekly  \
# 0       1001   17  Female  Caucasian      Some College        19.833723
# 1       1002   18    Male  Caucasian       High School        15.408756
# 2       1003   15    Male      Asian        Bachelor's         4.210570
# 3       1004   17  Female  Caucasian        Bachelor's        10.028829
# 4       1005   17  Female  Caucasian      Some College         4.672495
#
#    Absences  Tutoring ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1            None                0       0      1
# 1         0         0             Low                0       0      0
# 2        26         0            None                0       0      0
# 3        14         0            High                1       0      0
# 4        17         1            High                0       0      0
#
#    Volunteering       GPA  GradeClass PerentalEducation
# ...

# %%
df.loc[df["ParentalSupport"] == 0, "ParentalSupport"] = "None"
df.loc[df["ParentalSupport"] == 1, "ParentalSupport"] = "Low"
df.loc[df["ParentalSupport"] == 2, "ParentalSupport"] = "Moderate"
df.loc[df["ParentalSupport"] == 3, "ParentalSupport"] = "High"
df.loc[df["ParentalSupport"] == 4, "ParentalSupport"] = " Very High"

# %%
df
# Out:
#       StudentID  Age  Gender         Ethnicity ParentalEducation  \
# 0          1001   17  Female         Caucasian      Some College
# 1          1002   18    Male         Caucasian       High School
# 2          1003   15    Male             Asian        Bachelor's
# 3          1004   17  Female         Caucasian        Bachelor's
# 4          1005   17  Female         Caucasian      Some College
# ...         ...  ...     ...               ...               ...
# 2387       3388   18  Female         Caucasian        Bachelor's
# 2388       3389   17    Male         Caucasian       High School
# 2389       3390   16  Female         Caucasian      Some College
# 2390       3391   16  Female  African American              None
# 2391       3392   16  Female         Caucasian      Some College
#
#       StudyTimeWeekly  Absences  Tutoring ParentalSupport  Extracurricular  \
# 0           19.833723         7         1            None                0
# ...

# %% [markdown]
# ## Stipplot

# %%
sns.stripplot(data =df,
              y= "ParentalEducation",
              x= "StudyTimeWeekly",
              hue = "ParentalEducation")
# Out:
# <Axes: xlabel='StudyTimeWeekly', ylabel='ParentalEducation'>

# %%
df["Ethnicity"].value_counts()
# Out:
# Ethnicity
# Caucasian           1207
# African American     493
# Asian                470
# Other                222
# Name: count, dtype: int64

# %%
sns.swarmplot(data =df,
              y= "ParentalEducation",
              x= "StudyTimeWeekly",
              hue = "ParentalEducation")
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 39.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 26.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 7.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='StudyTimeWeekly', ylabel='ParentalEducation'>
# ...

# %%
sns.boxplot(data =df,
              y= "ParentalEducation",
              x= "StudyTimeWeekly",
              hue = "ParentalEducation")
# Out:
# <Axes: xlabel='StudyTimeWeekly', ylabel='ParentalEducation'>

# %%
sns.violinplot(data =df,
              y= "ParentalEducation",
              x= "StudyTimeWeekly",
              hue = "ParentalEducation")
# Out:
# <Axes: xlabel='StudyTimeWeekly', ylabel='ParentalEducation'>

# %%
sns.boxenplot(data =df,
              y= "ParentalEducation",
              x= "StudyTimeWeekly",
              hue = "ParentalEducation")
# Out:
# <Axes: xlabel='StudyTimeWeekly', ylabel='ParentalEducation'>

# %%
sns.barplot(data =df,
              y= "ParentalEducation",
              x= "StudyTimeWeekly",
              hue = "Ethnicity")
# Out:
# <Axes: xlabel='StudyTimeWeekly', ylabel='ParentalEducation'>

# %%
sns.pointplot(data =df,
              y= "ParentalEducation",
              x= "StudyTimeWeekly",
              hue = "Ethnicity")
# Out:
# <Axes: xlabel='StudyTimeWeekly', ylabel='ParentalEducation'>

# %%
sns.countplot(data= df, y="GradeClass", hue= "Absences" )
# Out:
# <Axes: xlabel='count', ylabel='GradeClass'>

# %%
df
# Out:
#       StudentID  Age  Gender         Ethnicity ParentalEducation  \
# 0          1001   17  Female         Caucasian      Some College
# 1          1002   18    Male         Caucasian       High School
# 2          1003   15    Male             Asian        Bachelor's
# 3          1004   17  Female         Caucasian        Bachelor's
# 4          1005   17  Female         Caucasian      Some College
# ...         ...  ...     ...               ...               ...
# 2387       3388   18  Female         Caucasian        Bachelor's
# 2388       3389   17    Male         Caucasian       High School
# 2389       3390   16  Female         Caucasian      Some College
# 2390       3391   16  Female  African American              None
# 2391       3392   16  Female         Caucasian      Some College
#
#       StudyTimeWeekly  Absences  Tutoring ParentalSupport  Extracurricular  \
# 0           19.833723         7         1            None                0
# ...

# %%
sns.regplot(data= df, x= "Absences",
            y = "GPA",
            marker = "+")
# Out:
# <Axes: xlabel='Absences', ylabel='GPA'>

# %%
sns.residplot(data= df, x= "Absences",
            y = "GPA")
# Out:
# <Axes: xlabel='Absences', ylabel='GPA'>

# %%
sns.regplot(data= df, x= "Absences",
            y = "GPA",
            order = 2)
# Out:
# <Axes: xlabel='Absences', ylabel='GPA'>

# %%
sns.residplot(data= df, x= "Absences",
            y = "GPA",
            order = 2)
# Out:
# <Axes: xlabel='Absences', ylabel='GPA'>

# %%
sns.regplot(data= df, x= "Absences",
            y = "GPA",
            x_jitter=.1, order= 2)
# Out:
# <Axes: xlabel='Absences', ylabel='GPA'>

# %%
sns.regplot(data= df, x= "Absences",
            y = "GPA",
            x_estimator=np.mean, order = 2)
# Out:
# <Axes: xlabel='Absences', ylabel='GPA'>

# %%
sns.regplot(data = df, x= "Absences",
            y= "GPA", x_bins=4)
# Out:
# <Axes: xlabel='Absences', ylabel='GPA'>

# %%
url = "https://assets.datacamp.com/production/repositories/2210/datasets/fb4f2c1039e3df2c2e2624a8c95de5a1980861c6/bike_share.csv"
df2= pd.read_csv(url)
df2.head()
# Out:
#        dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0  2011-01-01       1   0     1        0        6           0           2
# 1  2011-01-02       1   0     1        0        0           0           2
# 2  2011-01-03       1   0     1        0        1           1           1
# 3  2011-01-04       1   0     1        0        2           1           1
# 4  2011-01-05       1   0     1        0        3           1           1
#
#        temp     atemp       hum  windspeed  casual  registered  total_rentals
# 0  0.344167  0.363625  0.805833   0.160446     331         654            985
# 1  0.363478  0.353739  0.696087   0.248539     131         670            801
# 2  0.196364  0.189405  0.437273   0.248309     120        1229           1349
# 3  0.200000  0.212122  0.590435   0.160296     108        1454           1562
# 4  0.226957  0.229270  0.436957   0.186900      82        1518           1600

# %%
sns.heatmap(pd.crosstab(df2["mnth"], df2["weekday"],
            values=df2["total_rentals"], aggfunc="mean"))
# Out:
# <Axes: xlabel='weekday', ylabel='mnth'>

# %%
sns.heatmap(pd.crosstab(df2["mnth"], df2["weekday"],
            values=df2["total_rentals"], aggfunc="mean").astype(int), annot = True, fmt="d",
            cmap="YlGnBu", cbar=True, linewidths=0.5)
# Out:
# <Axes: xlabel='weekday', ylabel='mnth'>

# %%
cols = ['total_rentals', 'temp', 'casual', 'hum', 'windspeed']
sns.heatmap(df2[cols].corr(), cmap="YlGnBu")
# Out:
# <Axes: >
