# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("medicare_data.csv", encoding= "latin1")
df
# Out:
#         Rndrng_Prvdr_CCN                Rndrng_Prvdr_Org_Name  \
# 0                  10001      Southeast Health Medical Center
# 1                  10001      Southeast Health Medical Center
# 2                  10001      Southeast Health Medical Center
# 3                  10001      Southeast Health Medical Center
# 4                  10001      Southeast Health Medical Center
# ...                  ...                                  ...
# 145737            670300  Methodist Midlothian Medical Center
# 145738            670300  Methodist Midlothian Medical Center
# 145739            670309      Texas Health Hospital Mansfield
# 145740            670309      Texas Health Hospital Mansfield
# 145741            670309      Texas Health Hospital Mansfield
#
#        Rndrng_Prvdr_City         Rndrng_Prvdr_St  Rndrng_Prvdr_State_FIPS  \
# 0                 Dothan  1108 Ross Clark Circle                        1
# ...

# %%
df.columns
# Out:
# Index(['Rndrng_Prvdr_CCN', 'Rndrng_Prvdr_Org_Name', 'Rndrng_Prvdr_City',
#        'Rndrng_Prvdr_St', 'Rndrng_Prvdr_State_FIPS', 'Rndrng_Prvdr_Zip5',
#        'Rndrng_Prvdr_State_Abrvtn', 'Rndrng_Prvdr_RUCA',
#        'Rndrng_Prvdr_RUCA_Desc', 'DRG_Cd', 'DRG_Desc', 'Tot_Dschrgs',
#        'Avg_Submtd_Cvrd_Chrg', 'Avg_Tot_Pymt_Amt', 'Avg_Mdcr_Pymt_Amt'],
#       dtype='object')

# %%
sns.stripplot(data=df, y="Rndrng_Prvdr_RUCA_Desc",
              x= "DRG_Cd")
# Out:
# <Axes: xlabel='DRG_Cd', ylabel='Rndrng_Prvdr_RUCA_Desc'>

# %%
df1= df.loc[df["DRG_Cd"]==682]

# %%
df1
# Out:
#         Rndrng_Prvdr_CCN                             Rndrng_Prvdr_Org_Name  \
# 87                 10001                   Southeast Health Medical Center
# 128                10005             Marshall Medical Centers South Campus
# 193                10006                      North Alabama Medical Center
# 258                10011                                 St Vincent's East
# 308                10016                     Shelby Baptist Medical Center
# ...                  ...                                               ...
# 145555            670103                             Medical City Alliance
# 145565            670106                   Hca Houston Healthcare Pearland
# 145606            670120  The Hospitals Of Providence Transmountain Campus
# 145696            670122          Houston Methodist The Woodlands Hospital
# 145725            670260                      Texas Health Hospital Frisco
#
# ...

# %%
sns.stripplot(data=df1, x="Avg_Submtd_Cvrd_Chrg",
              y= "DRG_Cd")
# Out:
# <Axes: xlabel='Avg_Submtd_Cvrd_Chrg', ylabel='DRG_Cd'>

# %%
df[df["DRG_Cd"].isin([682,683,684])]
# Out:
#         Rndrng_Prvdr_CCN                             Rndrng_Prvdr_Org_Name  \
# 87                 10001                   Southeast Health Medical Center
# 88                 10001                   Southeast Health Medical Center
# 128                10005             Marshall Medical Centers South Campus
# 129                10005             Marshall Medical Centers South Campus
# 193                10006                      North Alabama Medical Center
# ...                  ...                                               ...
# 145606            670120  The Hospitals Of Providence Transmountain Campus
# 145696            670122          Houston Methodist The Woodlands Hospital
# 145697            670122          Houston Methodist The Woodlands Hospital
# 145725            670260                      Texas Health Hospital Frisco
# 145726            670260                      Texas Health Hospital Frisco
#
# ...

# %%
sns.stripplot(data=df, x="Avg_Submtd_Cvrd_Chrg",
              y= df[df["DRG_Cd"].isin([682,683,684])]["DRG_Desc"],
              hue= df[df["DRG_Cd"].isin([682,683,684])]["DRG_Desc"]
              )
# Out:
# <Axes: xlabel='Avg_Submtd_Cvrd_Chrg', ylabel='DRG_Desc'>

# %%
sns.swarmplot(data=df, x="Avg_Submtd_Cvrd_Chrg",
              y= df[df["DRG_Cd"].isin([682,683,684])]["DRG_Desc"],
              hue= df[df["DRG_Cd"].isin([682,683,684])]["DRG_Desc"]
              )
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 76.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 82.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Avg_Submtd_Cvrd_Chrg', ylabel='DRG_Desc'>
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 82.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.boxplot(data=df[df["DRG_Cd"].isin([682,683,684])], x="Avg_Submtd_Cvrd_Chrg",
              y= "DRG_Desc",
              hue= "DRG_Desc"
              )
# Out:
# <Axes: xlabel='Avg_Submtd_Cvrd_Chrg', ylabel='DRG_Desc'>

# %%
sns.violinplot(data=df[df["DRG_Cd"].isin([682,683,684])], x="Avg_Submtd_Cvrd_Chrg",
              y= "DRG_Desc",
              hue= "DRG_Desc"
              )
# Out:
# <Axes: xlabel='Avg_Submtd_Cvrd_Chrg', ylabel='DRG_Desc'>

# %%
sns.boxenplot(data=df[df["DRG_Cd"].isin([682,683,684])], x="Avg_Submtd_Cvrd_Chrg",
              y= "DRG_Desc",
              hue= "DRG_Desc"
              )
# Out:
# <Axes: xlabel='Avg_Submtd_Cvrd_Chrg', ylabel='DRG_Desc'>

# %%
sns.barplot(data=df[df["DRG_Cd"].isin([682,683,684])], x="Avg_Submtd_Cvrd_Chrg",
              y= "DRG_Desc",
              hue= "DRG_Desc"
              )
# Out:
# <Axes: xlabel='Avg_Submtd_Cvrd_Chrg', ylabel='DRG_Desc'>

# %%
url = "https://assets.datacamp.com/production/repositories/2210/datasets/fb4f2c1039e3df2c2e2624a8c95de5a1980861c6/bike_share.csv"
df2= pd.read_csv(url)
df2.head()
# Out:
#        dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0  2011-01-01       1   0     1        0        6           0           2
# 1  2011-01-02       1   0     1        0        0           0           2
# 2  2011-01-03       1   0     1        0        1           1           1
# 3  2011-01-04       1   0     1        0        2           1           1
# 4  2011-01-05       1   0     1        0        3           1           1
#
#        temp     atemp       hum  windspeed  casual  registered  total_rentals
# 0  0.344167  0.363625  0.805833   0.160446     331         654            985
# 1  0.363478  0.353739  0.696087   0.248539     131         670            801
# 2  0.196364  0.189405  0.437273   0.248309     120        1229           1349
# 3  0.200000  0.212122  0.590435   0.160296     108        1454           1562
# 4  0.226957  0.229270  0.436957   0.186900      82        1518           1600

# %%
sns.regplot(data=df2, x="temp",
            y= "total_rentals",
             marker='+' )
# Out:
# <Axes: xlabel='temp', ylabel='total_rentals'>

# %%
sns.residplot(data =df2,
              x= "temp", y= "total_rentals")
# Out:
# <Axes: xlabel='temp', ylabel='total_rentals'>

# %%
sns.regplot(data =df2,
              x= "temp", y= "total_rentals",
              order=2)
# Out:
# <Axes: xlabel='temp', ylabel='total_rentals'>

# %%
sns.regplot(data= df2,
            x= "mnth",
            y= "total_rentals",
            x_jitter=.1, order= 2)
# Out:
# <Axes: xlabel='mnth', ylabel='total_rentals'>

# %%
import numpy as np

# %%
sns.regplot(data= df2,
            x= "mnth",
            y= "total_rentals",
            x_estimator=np.mean, order= 2)
# Out:
# <Axes: xlabel='mnth', ylabel='total_rentals'>

# %%
sns.regplot(data= df2,
            x= "temp",
            y= "total_rentals",
            order=2,
            x_bins=4)
# Out:
# <Axes: xlabel='temp', ylabel='total_rentals'>

# %%
sns.heatmap(pd.crosstab(df2["mnth"], df2["weekday"],
            values=df2["total_rentals"], aggfunc="mean"))
# Out:
# <Axes: xlabel='weekday', ylabel='mnth'>

# %%
sns.heatmap(pd.crosstab(df2["mnth"], df2["weekday"],
            values=df2["total_rentals"], aggfunc="mean").astype(int), annot = True, fmt="d",
            cmap="YlGnBu", cbar=True, linewidths=0.5)
# Out:
# <Axes: xlabel='weekday', ylabel='mnth'>

# %%
sns.heatmap(pd.crosstab(df2["mnth"], df2["weekday"],
            values=df2["total_rentals"], aggfunc="mean").astype(int), annot = True, fmt="d",
            cmap="YlGnBu", cbar=True, center=pd.crosstab(df2["mnth"], df2["weekday"],
            values=df2["total_rentals"], aggfunc="mean").loc[9,3] )
# Out:
# <Axes: xlabel='weekday', ylabel='mnth'>

# %%
df_crosstab =pd.crosstab(df2["mnth"], df2["weekday"],
            values=df2["total_rentals"], aggfunc="mean")

# %%
cols = ['total_rentals', 'temp', 'casual', 'hum', 'windspeed']
sns.heatmap(df2[cols].corr(), cmap="YlGnBu")
# Out:
# <Axes: >

# %%
df2[cols].corr()
# Out:
#                total_rentals      temp    casual       hum  windspeed
# total_rentals       1.000000  0.627494  0.672804 -0.100659  -0.234545
# temp                0.627494  1.000000  0.543285  0.126963  -0.157944
# casual              0.672804  0.543285  1.000000 -0.077008  -0.167613
# hum                -0.100659  0.126963 -0.077008  1.000000  -0.248489
# windspeed          -0.234545 -0.157944 -0.167613 -0.248489   1.000000

# %%
sns.heatmap(df2[cols].corr(), cmap= 'YlGnBu')
# Out:
# <Axes: >
