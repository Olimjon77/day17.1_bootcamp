# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("Combined_DS_v10.csv")
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   SurveyDate                  999 non-null    object
#  1   FormalEducation             999 non-null    object
#  2   ConvertedSalary             665 non-null    float64
#  3   Hobby                       999 non-null    object
#  4   Country                     999 non-null    object
#  5   StackOverflowJobsRecommend  487 non-null    float64
#  6   VersionControl              999 non-null    object
#  7   Age                         999 non-null    int64
#  8   Years Experience            999 non-null    int64
#  9   Gender                      693 non-null    object
#  10  RawSalary                   665 non-null    object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 86.0+ KB
# ...

# %%
df.isnull()
# Out:
#      SurveyDate  FormalEducation  ConvertedSalary  Hobby  Country  \
# 0         False            False             True  False    False
# 1         False            False            False  False    False
# 2         False            False             True  False    False
# 3         False            False            False  False    False
# 4         False            False            False  False    False
# ..          ...              ...              ...    ...      ...
# 994       False            False             True  False    False
# 995       False            False            False  False    False
# 996       False            False            False  False    False
# 997       False            False             True  False    False
# 998       False            False            False  False    False
#
#      StackOverflowJobsRecommend  VersionControl    Age  Years Experience  \
# 0                          True           False  False             False
# ...

# %%
df.isnull().sum()
# Out:
# SurveyDate                      0
# FormalEducation                 0
# ConvertedSalary               334
# Hobby                           0
# Country                         0
# StackOverflowJobsRecommend    512
# VersionControl                  0
# Age                             0
# Years Experience                0
# Gender                        306
# RawSalary                     334
# dtype: int64

# %%
df.isnull().sum().sum()
df.head()
# Out:
#       SurveyDate                                    FormalEducation  \
# 0  2/28/18 20:20           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1  6/28/18 13:26           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2    6/6/18 3:37           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3    5/9/18 1:06  Some college/university study without earning ...
# 4  4/12/18 22:41           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#    ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# 0              NaN   Yes  South Africa                         NaN
# 1          70841.0   Yes       Sweeden                         7.0
# 2              NaN    No       Sweeden                         8.0
# 3          21426.0   Yes       Sweeden                         NaN
# 4          41671.0   Yes            UK                         8.0
#
#       VersionControl  Age  Years Experience Gender   RawSalary
# 0                Git   21                13   Male         NaN
# ...

# %%
print(df.shape)
# Out:
# (999, 11)

# %%
df.head()
# Out:
#       SurveyDate                                    FormalEducation  \
# 0  2/28/18 20:20           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1  6/28/18 13:26           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2    6/6/18 3:37           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3    5/9/18 1:06  Some college/university study without earning ...
# 4  4/12/18 22:41           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#    ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# 0              NaN   Yes  South Africa                         NaN
# 1          70841.0   Yes       Sweeden                         7.0
# 2              NaN    No       Sweeden                         8.0
# 3          21426.0   Yes       Sweeden                         NaN
# 4          41671.0   Yes            UK                         8.0
#
#       VersionControl  Age  Years Experience Gender   RawSalary
# 0                Git   21                13   Male         NaN
# ...

# %%
new_df= df.dropna(how = "any")
df.head()
# Out:
#       SurveyDate                                    FormalEducation  \
# 0  2/28/18 20:20           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1  6/28/18 13:26           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2    6/6/18 3:37           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3    5/9/18 1:06  Some college/university study without earning ...
# 4  4/12/18 22:41           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#    ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# 0              NaN   Yes  South Africa                         NaN
# 1          70841.0   Yes       Sweeden                         7.0
# 2              NaN    No       Sweeden                         8.0
# 3          21426.0   Yes       Sweeden                         NaN
# 4          41671.0   Yes            UK                         8.0
#
#       VersionControl  Age  Years Experience Gender   RawSalary
# 0                Git   21                13   Male         NaN
# ...

# %%
print(new_df.shape)
# Out:
# (264, 11)

# %%
df.dropna(subset=["Gender"]).shape
# Out:
# (693, 11)

# %%
df.head()
# Out:
#       SurveyDate                                    FormalEducation  \
# 0  2/28/18 20:20           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1  6/28/18 13:26           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2    6/6/18 3:37           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3    5/9/18 1:06  Some college/university study without earning ...
# 4  4/12/18 22:41           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#    ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# 0              NaN   Yes  South Africa                         NaN
# 1          70841.0   Yes       Sweeden                         7.0
# 2              NaN    No       Sweeden                         8.0
# 3          21426.0   Yes       Sweeden                         NaN
# 4          41671.0   Yes            UK                         8.0
#
#       VersionControl  Age  Years Experience Gender   RawSalary
# 0                Git   21                13   Male         NaN
# ...

# %%
df["Gende_not_null"]= df["Gender"].fillna(value="G'anisher")

# %%
df.head()
# Out:
#       SurveyDate                                    FormalEducation  \
# 0  2/28/18 20:20           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1  6/28/18 13:26           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2    6/6/18 3:37           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3    5/9/18 1:06  Some college/university study without earning ...
# 4  4/12/18 22:41           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#    ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# 0              NaN   Yes  South Africa                         NaN
# 1          70841.0   Yes       Sweeden                         7.0
# 2              NaN    No       Sweeden                         8.0
# 3          21426.0   Yes       Sweeden                         NaN
# 4          41671.0   Yes            UK                         8.0
#
#       VersionControl  Age  Years Experience Gender   RawSalary Gende_not_null
# ...

# %%
print(df['ConvertedSalary'].mean())
print(df['ConvertedSalary'].median())
print(df['ConvertedSalary'].mode())
# Out:
# 92565.16992481203
# 55562.0
# 0    120000.0
# Name: ConvertedSalary, dtype: float64

# %%
df['ConvertedSalary'] = df['ConvertedSalary'].fillna(df['ConvertedSalary'].median())

# %%
df
# Out:
#          SurveyDate                                    FormalEducation  \
# 0     2/28/18 20:20           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1     6/28/18 13:26           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2       6/6/18 3:37           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3       5/9/18 1:06  Some college/university study without earning ...
# 4     4/12/18 22:41           Bachelor's degree (BA. BS. B.Eng.. etc.)
# ..              ...                                                ...
# 994  10/19/18 13:50  Some college/university study without earning ...
# 995   4/14/18 15:31           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 996    3/21/18 6:34           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 997    2/5/18 20:01           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 998   2/11/18 21:23           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#      ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# ...

# %%
df['ConvertedSalary'] = df["ConvertedSalary"].astype("int64")
df.head()
# Out:
#       SurveyDate                                    FormalEducation  \
# 0  2/28/18 20:20           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1  6/28/18 13:26           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2    6/6/18 3:37           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3    5/9/18 1:06  Some college/university study without earning ...
# 4  4/12/18 22:41           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#    ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# 0            55562   Yes  South Africa                         NaN
# 1            70841   Yes       Sweeden                         7.0
# 2            55562    No       Sweeden                         8.0
# 3            21426   Yes       Sweeden                         NaN
# 4            41671   Yes            UK                         8.0
#
#       VersionControl  Age  Years Experience Gender   RawSalary Gende_not_null
# ...

# %%
type(df['ConvertedSalary'])
# Out:
# pandas.core.series.Series

# %%
df['ConvertedSalary'].dtype
# Out:
# dtype('int64')

# %%
df['RawSalary'] = df['RawSalary'].str.replace(',', '')

# %%
df
# Out:
#          SurveyDate                                    FormalEducation  \
# 0     2/28/18 20:20           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1     6/28/18 13:26           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2       6/6/18 3:37           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3       5/9/18 1:06  Some college/university study without earning ...
# 4     4/12/18 22:41           Bachelor's degree (BA. BS. B.Eng.. etc.)
# ..              ...                                                ...
# 994  10/19/18 13:50  Some college/university study without earning ...
# 995   4/14/18 15:31           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 996    3/21/18 6:34           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 997    2/5/18 20:01           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 998   2/11/18 21:23           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#      ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# ...

# %%
df['ClearSalary'] = df['RawSalary'].str.replace('[ۣ$]', '', regex=True)

# %%
df
# Out:
#          SurveyDate                                    FormalEducation  \
# 0     2/28/18 20:20           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1     6/28/18 13:26           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2       6/6/18 3:37           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3       5/9/18 1:06  Some college/university study without earning ...
# 4     4/12/18 22:41           Bachelor's degree (BA. BS. B.Eng.. etc.)
# ..              ...                                                ...
# 994  10/19/18 13:50  Some college/university study without earning ...
# 995   4/14/18 15:31           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 996    3/21/18 6:34           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 997    2/5/18 20:01           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 998   2/11/18 21:23           Bachelor's degree (BA. BS. B.Eng.. etc.)
#
#      ConvertedSalary Hobby       Country  StackOverflowJobsRecommend  \
# ...

# %%
df['ClearSalary']= df['ClearSalary'].astype("float")

# %%
df["ClearSalary"].dtype
# Out:
# dtype('float64')

# %%
coerced_vals = pd.to_numeric(df["RawSalary"], errors= "coerce")

# %%
coerced_vals
# Out:
# 0            NaN
# 1        70841.0
# 2            NaN
# 3        21426.0
# 4            NaN
#          ...
# 994          NaN
# 995      58746.0
# 996          NaN
# 997          NaN
# 998    1000000.0
# Name: RawSalary, Length: 999, dtype: float64
