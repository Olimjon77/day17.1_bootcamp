# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("example.csv")

# %% [markdown]
# ## Dataset haqida malumot

# %%
df.describe()
# Out:
#           Unnamed: 0        Safety        yacEPA         Drive  \
# count   40769.000000  40769.000000  15867.000000  40769.000000
# mean   202916.414359      0.000294     -0.396137     12.287817
# std    117725.700085      0.017154      1.998663      7.169334
# min        47.000000      0.000000    -14.000000      1.000000
# 25%    101844.000000      0.000000     -0.961252      6.000000
# 50%    201785.000000      0.000000      0.000000     12.000000
# 75%    304505.000000      0.000000      0.484938     18.000000
# max    407658.000000      1.000000      8.390143     34.000000
#
#        FieldGoalDistance        airEPA  Field_Goal_Prob  Penalty.Yards  \
# count         902.000000  15875.000000     40748.000000   40769.000000
# mean           37.487805      0.522389         0.243680       0.607349
# std            10.049785      1.399720         0.159400       2.585225
# min            18.000000     -5.930319         0.000000       0.000000
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Safety    yacEPA  Drive  FieldGoalDistance    airEPA  \
# 0      244485       0  1.240299     18                NaN -0.588101
# 1      115340       0       NaN     22                NaN       NaN
# 2       68357       0       NaN      8                NaN       NaN
# 3      368377       0  1.075660     24                NaN  0.402080
# 4      384684       0       NaN     11                NaN       NaN
#
#    Field_Goal_Prob posteam  Penalty.Yards FieldGoalResult  ...  \
# 0         0.309404      TB              0             NaN  ...
# 1         0.198142     OAK              0             NaN  ...
# 2         0.000000     NYJ              0             NaN  ...
# 3         0.258227     CLE              0             NaN  ...
# 4         0.199771     DEN              0             NaN  ...
#
#    Accepted.Penalty qtr  AwayTimeouts_Remaining_Post  RunGap  Reception  \
# 0                 0   3                            3     NaN          1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40769 entries, 0 to 40768
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   40769 non-null  int64
#  1   Safety                       40769 non-null  int64
#  2   yacEPA                       15867 non-null  float64
#  3   Drive                        40769 non-null  int64
#  4   FieldGoalDistance            902 non-null    float64
#  5   airEPA                       15875 non-null  float64
#  6   Field_Goal_Prob              40748 non-null  float64
#  7   posteam                      38219 non-null  object
#  8   Penalty.Yards                40769 non-null  int64
#  9   FieldGoalResult              908 non-null    object
#  10  DefTeamScore                 38019 non-null  float64
#  11  Tackler2                     4943 non-null   object
#  12  Away_WP_pre                  38223 non-null  float64
# ...

# %% [markdown]
# ## Isnull orqli none malumomotlarni columndagi sonini aniqlash

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                         0
# Safety                             0
# yacEPA                         24902
# Drive                              0
# FieldGoalDistance              39867
# airEPA                         24894
# Field_Goal_Prob                   21
# posteam                         2550
# Penalty.Yards                      0
# FieldGoalResult                39861
# DefTeamScore                    2750
# Tackler2                       35826
# Away_WP_pre                     2546
# Timeout_Indicator                  0
# ydsnet                             0
# TimeSecs                          27
# Passer                         24073
# Touchdown                          0
# TwoPointConv                   40716
# PassOutcome                    24018
# PlayTimeDiff                      43
# RushAttempt                        0
# Accepted.Penalty                   0
# qtr                                0
# AwayTimeouts_Remaining_Post        0
# ...

# %%
df.shape
# Out:
# (40769, 32)

# %% [markdown]
# ## Barcha bo'sh malumotlarni o'chirish

# %%
new_df= df.dropna(how= "any")
print(new_df.shape)
# Out:
# (0, 32)

# %%
new_df.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Safety, yacEPA, Drive, FieldGoalDistance, airEPA, Field_Goal_Prob, posteam, Penalty.Yards, FieldGoalResult, DefTeamScore, Tackler2, Away_WP_pre, Timeout_Indicator, ydsnet, TimeSecs, Passer, Touchdown, TwoPointConv, PassOutcome, PlayTimeDiff, RushAttempt, Accepted.Penalty, qtr, AwayTimeouts_Remaining_Post, RunGap, Reception, TimeUnder, Season, Opp_Safety_Prob, No_Score_Prob, Challenge.Replay]
# Index: []
#
# [0 rows x 32 columns]

# %%
df["DefTeamScore"].mode
# Out:
# <bound method Series.mode of 0        10.0
# 1        14.0
# 2        13.0
# 3        31.0
# 4        24.0
#          ...
# 40764     0.0
# 40765     0.0
# 40766    10.0
# 40767    13.0
# 40768     3.0
# Name: DefTeamScore, Length: 40769, dtype: float64>

# %%
df["DefTeamScore"].mean()
# Out:
# np.float64(11.366316841579211)

# %% [markdown]
# ## Fillna orqali bo'shlarini almashtirish

# %%
df["DefTeamScore_not_null"]= df["DefTeamScore"].fillna(value= df["DefTeamScore"].mean().astype("float64"))

# %%
df.head()
# Out:
#    Unnamed: 0  Safety    yacEPA  Drive  FieldGoalDistance    airEPA  \
# 0      244485       0  1.240299     18                NaN -0.588101
# 1      115340       0       NaN     22                NaN       NaN
# 2       68357       0       NaN      8                NaN       NaN
# 3      368377       0  1.075660     24                NaN  0.402080
# 4      384684       0       NaN     11                NaN       NaN
#
#    Field_Goal_Prob posteam  Penalty.Yards FieldGoalResult  ...  qtr  \
# 0         0.309404      TB              0             NaN  ...    3
# 1         0.198142     OAK              0             NaN  ...    4
# 2         0.000000     NYJ              0             NaN  ...    2
# 3         0.258227     CLE              0             NaN  ...    4
# 4         0.199771     DEN              0             NaN  ...    2
#
#   AwayTimeouts_Remaining_Post  RunGap  Reception  TimeUnder  Season  \
# 0                           3     NaN          1          1    2014
# ...

# %%
df["DefTeamScore"].dtype
# Out:
# dtype('float64')
