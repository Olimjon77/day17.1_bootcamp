# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
url= 'https://assets.datacamp.com/production/repositories/2210/datasets/794e0759b73a2d80baa5d8fb88636a47965139d3/college_datav3.csv'
df= pd.read_csv(url)
df.head()
# Out:
#                                 INSTNM    OPEID  REGION  SAT_AVG_ALL  PCTPELL  \
# 0             Alabama A & M University   100200       5        850.0   0.7249
# 1  University of Alabama at Birmingham   105200       5       1147.0   0.3505
# 2                   Amridge University  2503400       5          NaN   0.7455
# 3  University of Alabama in Huntsville   105500       5       1221.0   0.3179
# 4             Alabama State University   100500       5        844.0   0.7567
#
#    PCTFLOAN  ADM_RATE_ALL       UG  AVGFACSAL COMPL_RPY_5YR_RT  ... CONTROL  \
# 0    0.8159      0.653841   4380.0     7017.0      0.477631579  ...       1
# 1    0.5218      0.604275  10331.0    10221.0      0.673230442  ...       1
# 2    0.8781           NaN     98.0     3217.0      0.636363636  ...       2
# 3    0.4589      0.811971   5220.0     9514.0      0.762222222  ...       1
# 4    0.7692      0.463858   4348.0     7940.0       0.43006993  ...       1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6702 entries, 0 to 6701
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   INSTNM            6702 non-null   object
#  1   OPEID             6702 non-null   int64
#  2   REGION            6702 non-null   int64
#  3   SAT_AVG_ALL       1387 non-null   float64
#  4   PCTPELL           6066 non-null   float64
#  5   PCTFLOAN          6066 non-null   float64
#  6   ADM_RATE_ALL      2180 non-null   float64
#  7   UG                4367 non-null   float64
#  8   AVGFACSAL         4104 non-null   float64
#  9   COMPL_RPY_5YR_RT  5708 non-null   object
#  10  DEBT_MDN          6681 non-null   object
#  11  MEDIAN_HH_INC     4993 non-null   object
#  12  ICLEVEL           6702 non-null   int64
#  13  HIGHDEG           6702 non-null   int64
#  14  CONTROL           6702 non-null   int64
#  15  WOMENONLY         6368 non-null   float64
# ...

# %%
df.describe()
# Out:
#               OPEID       REGION  SAT_AVG_ALL      PCTPELL     PCTFLOAN  \
# count  6.702000e+03  6702.000000  1387.000000  6066.000000  6066.000000
# mean   1.788528e+06     4.602954  1065.332372     0.502318     0.490676
# std    3.304120e+06     2.177145   134.879236     0.220404     0.279644
# min    1.002000e+05     0.000000   708.000000     0.000000     0.000000
# 25%    3.188250e+05     3.000000   981.500000     0.338525     0.285725
# 50%    1.005302e+06     5.000000  1048.000000     0.483850     0.548200
# 75%    2.598900e+06     6.000000  1127.000000     0.666700     0.704500
# max    8.209884e+07     9.000000  1544.000000     1.000000     1.000000
#
#        ADM_RATE_ALL            UG     AVGFACSAL      ICLEVEL      HIGHDEG  \
# count   2180.000000   4367.000000   4104.000000  6702.000000  6702.000000
# mean       0.681821   2945.242501   6451.342105     1.811698     2.276783
# std        0.204033   4974.178446   2376.043146     0.817686     1.324162
# ...

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6702 entries, 0 to 6701
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   INSTNM            6702 non-null   object
#  1   OPEID             6702 non-null   int64
#  2   REGION            6702 non-null   int64
#  3   SAT_AVG_ALL       1387 non-null   float64
#  4   PCTPELL           6066 non-null   float64
#  5   PCTFLOAN          6066 non-null   float64
#  6   ADM_RATE_ALL      2180 non-null   float64
#  7   UG                4367 non-null   float64
#  8   AVGFACSAL         4104 non-null   float64
#  9   COMPL_RPY_5YR_RT  5708 non-null   object
#  10  DEBT_MDN          6681 non-null   object
#  11  MEDIAN_HH_INC     4993 non-null   object
#  12  ICLEVEL           6702 non-null   int64
#  13  HIGHDEG           6702 non-null   int64
#  14  CONTROL           6702 non-null   int64
#  15  WOMENONLY         6368 non-null   float64
# ...

# %%
df.isna().sum()
# Out:
# INSTNM                 0
# OPEID                  0
# REGION                 0
# SAT_AVG_ALL         5315
# PCTPELL              636
# PCTFLOAN             636
# ADM_RATE_ALL        4522
# UG                  2335
# AVGFACSAL           2598
# COMPL_RPY_5YR_RT     994
# DEBT_MDN              21
# MEDIAN_HH_INC       1709
# ICLEVEL                0
# HIGHDEG                0
# CONTROL                0
# WOMENONLY            334
# MENONLY              334
# LOCALE               334
# Tuition              967
# Degree_Type            0
# Ownership              0
# Regions                0
# Locales              334
# Locale_Short         337
# dtype: int64

# %%
df.head().T
# Out:
#                                          0  \
# INSTNM            Alabama A & M University
# OPEID                               100200
# REGION                                   5
# SAT_AVG_ALL                          850.0
# PCTPELL                             0.7249
# PCTFLOAN                            0.8159
# ADM_RATE_ALL                      0.653841
# UG                                  4380.0
# AVGFACSAL                           7017.0
# COMPL_RPY_5YR_RT               0.477631579
# DEBT_MDN                             14600
# MEDIAN_HH_INC                     49720.22
# ICLEVEL                                  1
# HIGHDEG                                  4
# CONTROL                                  1
# WOMENONLY                              0.0
# MENONLY                                0.0
# LOCALE                                12.0
# Tuition                            13435.0
# Degree_Type                       Graduate
# Ownership                           Public
# ...

# %% [markdown]
# ## Obyektni numerikka o'tkazish

# %%
df["COMPL_RPY_5YR_RT"] = pd.to_numeric(df["COMPL_RPY_5YR_RT"], errors="coerce")
df["DEBT_MDN"] = pd.to_numeric(df["DEBT_MDN"], errors="coerce")
df["MEDIAN_HH_INC"] = pd.to_numeric(df["MEDIAN_HH_INC"], errors="coerce")

# %%
df.dtypes
# Out:
# INSTNM               object
# OPEID                 int64
# REGION                int64
# SAT_AVG_ALL         float64
# PCTPELL             float64
# PCTFLOAN            float64
# ADM_RATE_ALL        float64
# UG                  float64
# AVGFACSAL           float64
# COMPL_RPY_5YR_RT    float64
# DEBT_MDN            float64
# MEDIAN_HH_INC       float64
# ICLEVEL               int64
# HIGHDEG               int64
# CONTROL               int64
# WOMENONLY           float64
# MENONLY             float64
# LOCALE              float64
# Tuition             float64
# Degree_Type          object
# Ownership            object
# Regions              object
# Locales              object
# Locale_Short         object
# dtype: object

# %%
# df.dropna().reset_index(drop=True)

# %%
df["COMPL_RPY_5YR_RT"].isna().sum()
# Out:
# np.int64(2251)

# %% [markdown]
# ## Transform orqali nanlarni ozgartirish

# %%
df["COMPL_RPY_5YR_RT_FILLNA_median"] = df.groupby(["REGION", "Ownership"])["COMPL_RPY_5YR_RT"].transform(lambda x: x.fillna(x.median()))
df["COMPL_RPY_5YR_RT_FILLNA_mean"] = df.groupby(["REGION", "Ownership"])["COMPL_RPY_5YR_RT"].transform(lambda x: x.fillna(x.mean()))
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %% [markdown]
# ##  Plotta hist orqali bir nechta malumotlarni bitta ifodalash

# %%
fig, ax = plt.subplots(figsize= (10,6))
df["COMPL_RPY_5YR_RT"].plot(kind="hist", ax=ax, alpha=0.5, color="blue", bins=20, label= "Numeric")
df["COMPL_RPY_5YR_RT_FILLNA_median"].plot(kind="hist", ax=ax, alpha= 0.5, color= "green", bins= 20, label= "Fillna_Median")
df["COMPL_RPY_5YR_RT_FILLNA_mean"].plot(kind="hist", ax=ax, alpha= 0.5, color= "red", bins= 20, label= "Fillna_Mean")
ax.set_ylabel("Value")
ax.set_ylabel("Frequency")
ax.legend()
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize= (12,8))
df["COMPL_RPY_5YR_RT"].plot(kind="kde", ax=ax, alpha=0.5, color="blue",label= "Numeric")
df["COMPL_RPY_5YR_RT_FILLNA_median"].plot(kind="kde", ax=ax, alpha= 0.5, color= "green", label= "Fillna_Median")
df["COMPL_RPY_5YR_RT_FILLNA_mean"].plot(kind="kde", ax=ax, alpha= 0.5, color= "red", label= "Fillna_Mean")
ax.set_ylabel("Value")
ax.set_ylabel("Frequency")
ax.legend()
ax.set_title("COMPL_RPY_5YR_RT")
plt.grid()
plt.show()

# %%
df["DEBT_MDN_FILLNA_median"] = df.groupby(["REGION", "Ownership"])["DEBT_MDN"].transform(lambda x: x.fillna(x.median()))
df["DEBT_MDN_FILLNA_mean"] = df.groupby(["REGION", "Ownership"])["DEBT_MDN"].transform(lambda x: x.fillna(x.mean()))

# %%
fig, ax = plt.subplots(figsize= (8,5))
df["DEBT_MDN"].plot(kind="kde", ax=ax,  color="blue",label= "Numeric")
df["DEBT_MDN_FILLNA_median"].plot(kind="kde", ax=ax, color= "green", label= "Fillna_Median")
df["DEBT_MDN_FILLNA_mean"].plot(kind="kde", ax=ax, color= "red", label= "Fillna_Mean")
ax.set_ylabel("Value")
ax.set_ylabel("Frequency")
ax.legend()
ax.set_title("DEBT_MDN")
plt.grid()
plt.show()

# %%
df["PCTFLOAN_FILLNA_median"] = df.groupby(["REGION", "Ownership"])["PCTFLOAN"].transform(lambda x: x.fillna(x.median()))
df["PCTFLOAN_FILLNA_mean"] = df.groupby(["REGION", "Ownership"])["PCTFLOAN"].transform(lambda x: x.fillna(x.mean()))

# %%
fig, ax = plt.subplots(figsize= (8,5))
df["PCTFLOAN"].plot(kind="kde", ax=ax,  color="blue",label= "Numeric")
df["PCTFLOAN_FILLNA_median"].plot(kind="kde", ax=ax, color= "green", label= "Fillna_Median")
df["PCTFLOAN_FILLNA_mean"].plot(kind="kde", ax=ax, color= "red", label= "Fillna_Mean")
ax.set_ylabel("Value")
ax.set_ylabel("Frequency")
ax.legend()
ax.set_title("PCTFLOAN")
plt.grid()
plt.show()

# %%
g = sns.FacetGrid(df, col="Regions")
g.map(sns.boxplot,"MEDIAN_HH_INC")
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
df.head().T
# Out:
#                                                        0  \
# INSTNM                          Alabama A & M University
# OPEID                                             100200
# REGION                                                 5
# SAT_AVG_ALL                                        850.0
# PCTPELL                                           0.7249
# PCTFLOAN                                          0.8159
# ADM_RATE_ALL                                    0.653841
# UG                                                4380.0
# AVGFACSAL                                         7017.0
# COMPL_RPY_5YR_RT                                0.477632
# DEBT_MDN                                         14600.0
# MEDIAN_HH_INC                                   49720.22
# ICLEVEL                                                1
# HIGHDEG                                                4
# CONTROL                                                1
# ...

# %%
g= sns.PairGrid(df, vars= ["OPEID", "AVGFACSAL"])
g = g.map(sns.scatterplot)

# %%
g= sns.PairGrid(df, vars= ["OPEID", "AVGFACSAL"])
g = g.map_diag(sns.boxplot)
g =g.map_offdiag(sns.scatterplot)

# %%
sns.pairplot(df, vars= ["OPEID", "AVGFACSAL"], kind="reg",
             diag_kind="hist")

# %%
sns.pairplot(df.query("REGION <3"),
             vars= ["DEBT_MDN", "MEDIAN_HH_INC"],
             hue = "REGION", palette= "husl",
             plot_kws={"alpha":0.5})

# %%
g = sns.JointGrid(data= df, x= "Tuition", y= "ADM_RATE_ALL")
g.plot(sns.regplot, sns.histplot)

# %%
g = (sns.jointplot(x="Tuition",y="ADM_RATE_ALL",kind="scatter",xlim=(0, 25000),
                   data=df.query('UG < 2500 &Ownership == "Public"')).plot_joint(sns.kdeplot))
